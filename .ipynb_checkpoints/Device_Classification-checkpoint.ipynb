# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
with open('allMktData.txt', 'r') as f:
    app_data = []
    for line in f:
        app_data.append(line.split('\t'))

# %%
app_data[1]
# Out:
# ['com.AmorEsporadico.QC',
#  'AmorEsporadico buscar pareja',
#  'AmorEsporadico NO es una red social para encontrar sexo rápido. Es una red para citas entre solteros que buscan pareja sin compromisos a largo plazo. Una red social para ligar gratis, conocer gente nueva, chatear y tener citas.<br><br>Una App ideal para singles que no busquen relaciones serias ni matrimonio. Que deseen buscar mujeres solteras o hombres para una amistad y una relación casual. Para tener una cita romántica que no comprometa a ninguna de las partes, chatear y conocerse.<br><br>AmorEsporadico fomenta las relaciones sanas y desenfadadas pero con respeto y educación al resto de los miembros de nuestra red social.<br><br>Para tener citas casuales o citas sin compromiso puedes darte de alta y encontrar amigos y amigas de todas partes del mundo.Conocer nuevas personas con AmorEsporadico es gratis, sin cuotas mensuales. Con Amor Esporadico puedes hacer amigos nuevos, ligar y ampliar tu circulo de amistades.<br><br>• Es gratis: puedes chatear recibir y enviar mensajes, buscar otras personas para contectar con nuevos amigos y tener citas.<br><br>• Miles de perfiles: sube fotos, rellena tu perfil y haz contactos con miles de mujeres y hombres que podrás buscar en todo el mundo.<br><br>• Privada: Podrás dar de baja tu perfil son un solo click. No guardaremos tus datos (tampoco podrás reactivar la cuenta a futuro) te lo ponemos fácil para que puedas tener un control sobre tus datos y tu anonimato en la red.<br><br>• Perfiles compatibles: la app te permitirá encontrar personas con nuestro algoritmo de compatibilidad.<br><br>• Buscador: utiliza el buscar chicas o chicos con las características que te interesan.<br><br>• Donde tu elijas: en mi ciudad, en mi país o en otros países para conocer gente solo donde más te interesa.<br><br>Ligar hoy es más fácil que nunca y ahora gratis! Conocer gente cerca de ti, gente nueva y conseguir una amistad genial o una relación de pareja en una app de encuentros gratuita con más de medio millón de usuarios de todo el mundo.\n']

# %%
with open('installdata.tabseparatedtext', 'r') as f:
    device_data = []
    for line in f:
        device_data.append(line.split('\t')[:-1])

# %%
device_data = device_data[1:]

# %%
device_data[0]
# Out:
# [' HinKhoj.Dictionary                                 ',
#  ' cn.wps.moffice_eng                                 ',
#  ' cn.xender                                          ',
#  ' com.UCMobile.intl                                  ',
#  ' com.adobe.reader                                   ',
#  ' com.alibaba.aliexpresshd                           ',
#  ' com.avast.android.batterysaver                     ',
#  ' com.cleanmaster.mguard                             ',
#  ' com.eterno                                         ',
#  ' com.facebook.katana                                ',
#  ' com.facebook.orca                                  ',
#  ' com.google.android.apps.cloudprint                 ',
#  ' com.google.android.apps.maps                       ',
#  ' com.google.android.gm                              ',
#  ' com.google.android.gms                             ',
#  ' com.google.android.marvin.talkback                 ',
#  ' com.google.android.tts                             ',
#  ' com.google.android.videos                          ',
#  ' com.google.android.webview                         ',
#  ' com.google.android.youtube                         ',
#  ' com.hinkhoj.questionbank                           ',
#  ' com.jio.jioplay.tv                                 ',
#  ' com.jio.join                                       ',
#  ' com.jio.media.jiobeats                             ',
#  ' com.jio.myjio                                      ',
#  ' com.mxtech.videoplayer.ad                          ',
#  ' com.myairtelapp                                    ',
#  ' com.olx.southasia                                  ',
#  ' com.opera.max.global                               ',
#  ' com.opera.mini.native                              ',
#  ' com.reliancejio.mobilesecurity                     ',
#  ' com.saavn.android                                  ',
#  ' com.sonyliv                                        ',
#  ' com.teenpatti.hd.gold                              ',
#  ' com.truecaller                                     ',
#  ' com.uc.browser.en                                  ',
#  ' com.uc.iflow                                       ',
#  ' com.whatsapp                                       ',
#  ' cris.icms.ntes                                     ',
#  ' in.amazon.mShop.android.shopping                   ',
#  ' io.teslatech.callbreak                             ']

# %%
pd.read_csv('all-coded-apps.csv')
# Out:
#         dataset                                              appid  \
# 0        CR1MAP        com.phone.locationtracker.lookupphonenumber
# 1          2017                           allcall.location.tracker
# 2          2017                  bhabhi.tadka.number.location.desi
# 3          2017                      com.aappstech.gpsphonetracker
# 4          2017                    com.androidtech706.simphoneinfo
# ...         ...                                                ...
# 4080  2018/2019                       rizapps.secret.codes.samsung
# 4081  2018/2019  secret_codes.push_apps.free.secretcodesofallmo...
# 4082  2018/2019  secretcodes.iqratech.android.secretcodesofallm...
# 4083  2018/2019                            thanhnd.apps.hiddencode
# 4084     CR1MAP                 com.the4eminents.mobilesecretcodes
#
#                                                   title               code  \
# 0                                   Lookup Phone Number      callerid:misc
# 1                             All Call Location Tracker  callerid:location
# 2                         Live Location By Phone Number  callerid:location
# 3                                  Phone Number Locator  callerid:location
# 4                        Trace Call Phone Tracker Live.  callerid:location
# ...                                                 ...                ...
# 4080   NULL                                         ...  tutorial:settings
# 4081   All Mobiles Secret Codes book Free for Samsun...  tutorial:settings
# 4082                                                NaN  tutorial:settings
# 4083   Mobile Secret Codes - MMI USSD               ...  tutorial:settings
# 4084                                Mobile secret codes  tutorial:settings
#
#      more comments Comments more comments.1  \
# 0              NaN      NaN             NaN
# 1              NaN      NaN             NaN
# 2              NaN      NaN             NaN
# 3              NaN      NaN             NaN
# 4              NaN      NaN             NaN
# ...            ...      ...             ...
# 4080           NaN      NaN             NaN
# 4081           NaN      NaN             NaN
# 4082           NaN      NaN             NaN
# 4083           NaN      NaN             NaN
# 4084           NaN      NaN             NaN
#
#                                                best-url          genre  \
# 0                                                   NaN  COMMUNICATION
# 1                                                   NaN  COMMUNICATION
# 2                                                   NaN            NaN
# 3     https://apkpure.com/phone-number-locator/com.a...          TOOLS
# 4                                                   NaN  ENTERTAINMENT
# ...                                                 ...            ...
# 4080                                                NaN            NaN
# 4081                                                NaN            NaN
# 4082                                                NaN            NaN
# 4083                                                NaN            NaN
# 4084                                                NaN            NaN
#
#                                             permissions
# 0     android.permission.ACCESS_COARSE_LOCATION;andr...
# 1     allcall.location.tracker.permission.MAPS_RECEI...
# 2     android.permission.ACCESS_COARSE_LOCATION;andr...
# 3     android.permission.ACCESS_COARSE_LOCATION;andr...
# 4     android.permission.ACCESS_COARSE_LOCATION;andr...
# ...                                                 ...
# 4080                                                NaN
# 4081                                                NaN
# 4082                                                NaN
# 4083                                                NaN
# 4084  android.permission.ACCESS_NETWORK_STATE;androi...
#
# [4085 rows x 10 columns]
